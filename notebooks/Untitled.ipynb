# %%
using EmpiricalModeDecomposition
using PyPlot

# %%
samples = 50000
t = linspace(1,100,samples)
modei = [sin.(5*i.*t) for i in 5:-1:1]

modesi = [sum(modei[1:N]) for N in 2:5]

imfsi = [IMF(modesi[N-1], N=N) for N in 2:5]

for (n,imfs) in enumerate(imfsi)
    errs = [sum(abs.(imfs[:,N] .- modei[N]))/sum(abs.(modei[N])) for N in 1:(n+1)]
    println("Average Mode Recovery Error for $(n+1) Modes is: $errs")
end

println("""
    Assessing performance on simulated data:
        5 sin waves at freqs 25,20,15,10,5 Hz.
        Samples: $samples
        Noise: None
    """
)

for (n,imfs) in enumerate(imfsi)
    errs = [sum(abs.(imfs[:,N] .- modei[N]))/sum(abs.(modei[N])) for N in 1:(n+1)]
    println("Mode Recovery Error for $(n+1) Modes is:\n\tAverage $errs")
    
    edge = floor(Int,samples/5)
    errs = [sum(abs.(imfs[1:edge,N] .- modei[N][1:edge]))/sum(abs.(modei[N][1:edge])) for N in 1:(n+1)]
    println("\tEdge Effects: $errs")
    
    edge = floor(Int,samples/5)
    errs = [sum(abs.(imfs[edge:(end-edge),N] .- modei[N][edge:(end-edge)])
            )/sum(abs.(modei[N][edge:(end-edge)])) for N in 1:(n+1)]
    println("\tErrors without Edge Effects: $errs\n\n")
end
# Out:
# Average Mode Recovery Error for 2 Modes is: [0.163656, 0.254409]
# Average Mode Recovery Error for 3 Modes is: [0.184765, 0.257238, 0.178769]
# Average Mode Recovery Error for 4 Modes is: [0.185829, 0.252183, 0.167687, 0.435694]
# Average Mode Recovery Error for 5 Modes is: [0.187234, 0.243712, 0.161211, 0.182395, 0.0987092]

# %%
println("""
    Assessing performance on simulated data:
        5 sin waves at freqs 25,20,15,10,5 Hz.
        Samples: $samples
        Noise: None
    """
)

for (n,imfs) in enumerate(imfsi)
    errs = [sum(abs.(imfs[:,N] .- modei[N]))/sum(abs.(modei[N])) for N in 1:(n+1)]
    println("Mode Recovery Error for $(n+1) Modes is:\n\tAverage $errs")
    
    edge = floor(Int,samples/5)
    errs = [sum(abs.(imfs[1:edge,N] .- modei[N][1:edge]))/sum(abs.(modei[N][1:edge])) for N in 1:(n+1)]
    println("\tEdge Effects: $errs")
    
    edge = floor(Int,samples/5)
    errs = [sum(abs.(imfs[edge:(end-edge),N] .- modei[N][edge:(end-edge)])
            )/sum(abs.(modei[N][edge:(end-edge)])) for N in 1:(n+1)]
    println("\tErrors without Edge Effects: $errs\n\n")
end
# Out:
# Assessing performance on simulated data:
#     5 sin waves at freqs 25,20,15,10,5 Hz.
#     Samples: 50000
#     Noise: None
#
# Mode Recovery Error for 2 Modes is:
# 	Average [0.163656, 0.254409]
# 	Edge Effects: [0.234753, 0.553813]
# 	Errors without Edge Effects: [0.137237, 0.17105]
#
#
# Mode Recovery Error for 3 Modes is:
# 	Average [0.184765, 0.257238, 0.178769]
# 	Edge Effects: [0.288371, 0.527131, 0.3881]
# 	Errors without Edge Effects: [0.152674, 0.181558, 0.115834]
#
#
# Mode Recovery Error for 4 Modes is:
# 	Average [0.185829, 0.252183, 0.167687, 0.435694]
# 	Edge Effects: [0.296185, 0.521413, 0.366916, 0.213682]
# 	Errors without Edge Effects: [0.152987, 0.177576, 0.107308, 0.175176]
#
#
# Mode Recovery Error for 5 Modes is:
# 	Average [0.187234, 0.243712, 0.161211, 0.182395, 0.0987092]
# 	Edge Effects: [0.28524, 0.476158, 0.334253, 0.195124, 0.118631]
# 	Errors without Edge Effects: [0.152801, 0.177613, 0.107395, 0.172817, 0.0895668]

# %%
samples = 50000
# Out:
# 50000

# %%
plot(imfsi[4][:,4])
plot(modei[4])
figure()
plot(modei[1])
plot(modei[2])
plot(modei[4])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2ef8a39390>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2ef89af350>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f2ef88c2550>

# %%
plot(mode2)
plot(mode1)


figure()
plot(modes)

figure()
plot(imfs)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2f00b74c90>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2f00b59dd0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f2f00d0ac90>)
# 2-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f2f00de6250>
#  PyObject <matplotlib.lines.Line2D object at 0x7f2f00efd790>
